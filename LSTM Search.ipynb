# %% [markdown]
# # Imports

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import time

import numpy as np
import tensorflow as tf

from tensorflow.models.rnn import rnn_cell
from tensorflow.models.rnn.seq2seq import sequence_loss_by_example

# parses the dataset
import ptb_reader

# %% [markdown]
# # Dataset

# %%
train_data, valid_data, test_data, _ = ptb_reader.ptb_raw_data("/home/andy/data/ptb")

# %% [markdown]
# # Model

# %%
class PTBModel(object):
    def __init__(self, CellType, is_training, config):
        self.batch_size = batch_size = config.batch_size
        self.num_steps = num_steps = config.num_steps
        size = config.hidden_size
        vocab_size = config.vocab_size

        self.input_data = tf.placeholder(tf.int32, [batch_size, num_steps])
        self.targets = tf.placeholder(tf.int32, [batch_size, num_steps])

        lstm_cell = CellType(size)
        if is_training and config.keep_prob < 1:
            lstm_cell = rnn_cell.DropoutWrapper(lstm_cell, output_keep_prob=config.keep_prob)
        cell = rnn_cell.MultiRNNCell([lstm_cell] * config.num_layers)
        self.initial_state = cell.zero_state(batch_size, tf.float32)
        
        # initializer used for reusable variable initializer (see `get_variable`)
        initializer = tf.random_uniform_initializer(-config.init_scale, config.init_scale)

        with tf.device("/cpu:0"):
            embedding = tf.get_variable("embedding", [vocab_size, size], initializer=initializer)
            inputs = tf.nn.embedding_lookup(embedding, self.input_data)

        if is_training and config.keep_prob < 1:
            inputs = tf.nn.dropout(inputs, config.keep_prob)

        outputs = []
        states = []
        state = self.initial_state

        with tf.variable_scope("RNN", initializer=initializer):
            for time_step in range(num_steps):
                if time_step > 0:
                    tf.get_variable_scope().reuse_variables()

                inputs_slice = inputs[:,time_step,:]
                (cell_output, state) = cell(inputs_slice, state)

                outputs.append(cell_output)
                states.append(state)

        self.final_state = states[-1]

        output = tf.reshape(tf.concat(1, outputs), [-1, size])
        w = tf.get_variable("softmax_w",
                                    [size, vocab_size],
                                    initializer=initializer)
        b = tf.get_variable("softmax_b", [vocab_size], initializer=initializer)

        logits = tf.nn.xw_plus_b(output, w, b) # compute logits for loss
        targets = tf.reshape(self.targets, [-1]) # reshape our target outputs
        weights = tf.ones([batch_size * num_steps]) # used to scale the loss average

        # computes loss and performs softmax on our fully-connected output layer
        loss = sequence_loss_by_example([logits], [targets], [weights], vocab_size)
        self.cost = cost = tf.reduce_sum(loss) / batch_size

        if is_training:
            # define training operation and clip the gradients
            tvars = tf.trainable_variables()
            grads, _ = tf.clip_by_global_norm(tf.gradients(cost, tvars), config.max_grad_norm)
            optimizer = tf.train.MomentumOptimizer(config.learning_rate, config.momentum)
            self.train_op = optimizer.apply_gradients(zip(grads, tvars))
        else:
            # if this model isn't for training (i.e. testing/validation) then we don't do anything here
            self.train_op = tf.no_op()

# %% [markdown]
# # Epoch

# %%
def run_epoch(sess, model, data, is_training=False, verbose=False):
    epoch_size = ((len(data) // model.batch_size) - 1) // model.num_steps
    start_time = time.time()

    # accumulated counts
    costs = 0.0
    iters = 0

    # initial RNN state
    state = model.initial_state.eval()

    for step, (x, y) in enumerate(ptb_reader.ptb_iterator(data, model.batch_size, model.num_steps)):
        cost, state, _ = sess.run([model.cost, model.final_state, model.train_op], {
            model.input_data: x,
            model.targets: y,
            model.initial_state: state
        })
        costs += cost
        iters += model.num_steps

        perplexity = np.exp(costs / iters)

        if verbose and step % 10 == 0:
            progress = (step / epoch_size) * 100
            wps = iters * model.batch_size / (time.time() - start_time)
            print("%.1f%% perplexity: %.3f speed: %.0f wps" % (progress, perplexity, wps))

    return perplexity

# %% [markdown]
# # Config

# %%
class Config(object):
    batch_size = 50
    num_steps = 30
    hidden_size = 200
    vocab_size = 10000
    learning_rate = 1e-1
    momentum = 0.9
    max_grad_norm = 5
    init_scale = 0.1
    keep_prob = 0.5
    num_layers = 2

# %%
# default settings for training
train_config = Config()

# our evaluation runs (validation and testing), use a batch size and time step of one
eval_config = Config()
eval_config.batch_size = 1
eval_config.num_steps = 1

# number of training epochs to perform over the training data
num_epochs = 10

# %% [markdown]
# # Cell Variant

# %%
# here we import and specify our cell variant
# (all variants are subclasses of tensorflow.models.rnn.rnn_cell.RNNCell)
from variants.vanilla import VanillaLSTMCell
CellType = VanillaLSTMCell

# %%
with tf.Graph().as_default(), tf.Session() as sess:
    # define our training model
    with tf.variable_scope("model", reuse=None):
        train_model = PTBModel(CellType, is_training=True, config=train_config)

    # we create a separate model for validation and testing to alter the batch size and time steps
    # reuse=True reuses variables from the previously defined `train_model`
    with tf.variable_scope("model", reuse=True):
        valid_model = PTBModel(CellType, is_training=False, config=train_config)
        test_model = PTBModel(CellType, is_training=False, config=eval_config)

    sess.run(tf.initialize_all_variables())

    for i in range(num_epochs):
        # run training pass
        train_perplexity = run_epoch(sess, train_model, train_data, verbose=True)
        print("%i training complete, perplexity: %.3f" % (i, train_perplexity))

        # run validation pass
        valid_perplexity = run_epoch(sess, valid_model, valid_data)
        print("%i validation complete, perplexity: %.3f" % (i, valid_perplexity))

    # run test pass
    test_perplexity = run_epoch(sess, test_model, test_data)
    print("testing complete, perplexity: %.3f" % (test_perplexity,))
# Out:
# 0.0% perplexity: 9949.398 speed: 1579 wps
# 1.6% perplexity: 5751.059 speed: 7097 wps
# 3.2% perplexity: 2915.542 speed: 8535 wps
# 4.8% perplexity: 2088.120 speed: 9177 wps
# 6.5% perplexity: 1678.314 speed: 9549 wps
# 8.1% perplexity: 1472.646 speed: 9788 wps
# 9.7% perplexity: 1341.031 speed: 9954 wps
# 11.3% perplexity: 1239.907 speed: 10072 wps
# 12.9% perplexity: 1168.102 speed: 10166 wps
# 14.5% perplexity: 1110.246 speed: 10244 wps
# 16.2% perplexity: 1063.999 speed: 10308 wps
# 17.8% perplexity: 1020.040 speed: 10362 wps
# 19.4% perplexity: 983.485 speed: 10405 wps
# 21.0% perplexity: 946.975 speed: 10443 wps
# 22.6% perplexity: 914.264 speed: 10474 wps
# 24.2% perplexity: 884.428 speed: 10502 wps
# 25.8% perplexity: 856.497 speed: 10528 wps
# 27.5% perplexity: 831.311 speed: 10551 wps
# 29.1% perplexity: 810.854 speed: 10567 wps
# 30.7% perplexity: 790.955 speed: 10583 wps
# 32.3% perplexity: 771.032 speed: 10600 wps
# 33.9% perplexity: 753.972 speed: 10615 wps
# 35.5% perplexity: 737.361 speed: 10628 wps
# 37.2% perplexity: 719.565 speed: 10639 wps
# 38.8% perplexity: 704.578 speed: 10651 wps
# 40.4% perplexity: 693.236 speed: 10660 wps
# 42.0% perplexity: 679.497 speed: 10670 wps
# 43.6% perplexity: 669.815 speed: 10681 wps
# 45.2% perplexity: 659.064 speed: 10688 wps
# 46.8% perplexity: 648.005 speed: 10696 wps
# 48.5% perplexity: 637.754 speed: 10704 wps
# 50.1% perplexity: 629.358 speed: 10711 wps
# 51.7% perplexity: 622.183 speed: 10719 wps
# 53.3% perplexity: 613.867 speed: 10725 wps
# 54.9% perplexity: 605.458 speed: 10731 wps
# 56.5% perplexity: 597.380 speed: 10737 wps
# 58.2% perplexity: 588.408 speed: 10741 wps
# 59.8% perplexity: 580.534 speed: 10745 wps
# 61.4% perplexity: 573.660 speed: 10750 wps
# 63.0% perplexity: 566.978 speed: 10755 wps
# 64.6% perplexity: 561.017 speed: 10758 wps
# 66.2% perplexity: 554.764 speed: 10762 wps
# 67.9% perplexity: 547.607 speed: 10765 wps
# 69.5% perplexity: 540.769 speed: 10768 wps
# 71.1% perplexity: 535.104 speed: 10771 wps
# 72.7% perplexity: 530.268 speed: 10773 wps
# 74.3% perplexity: 524.848 speed: 10776 wps
# 75.9% perplexity: 519.871 speed: 10779 wps
# 77.5% perplexity: 514.414 speed: 10783 wps
# 79.2% perplexity: 509.819 speed: 10786 wps
# 80.8% perplexity: 505.863 speed: 10788 wps
# 82.4% perplexity: 501.833 speed: 10790 wps
# 84.0% perplexity: 498.267 speed: 10793 wps
# 85.6% perplexity: 494.267 speed: 10796 wps
# 87.2% perplexity: 489.933 speed: 10799 wps
# 88.9% perplexity: 486.136 speed: 10801 wps
# 90.5% perplexity: 481.492 speed: 10803 wps
# 92.1% perplexity: 478.201 speed: 10805 wps
# 93.7% perplexity: 474.865 speed: 10806 wps
# 95.3% perplexity: 471.675 speed: 10808 wps
# 96.9% perplexity: 468.495 speed: 10810 wps
# 98.5% perplexity: 465.367 speed: 10812 wps
# 0 training complete, perplexity: 463.103
# 0 validation complete, perplexity: 257.664
# 0.0% perplexity: 383.678 speed: 9303 wps
# 1.6% perplexity: 337.358 speed: 10743 wps
# 3.2% perplexity: 303.928 speed: 10822 wps
# 4.8% perplexity: 294.447 speed: 10838 wps
# 6.5% perplexity: 287.431 speed: 10865 wps
# 8.1% perplexity: 290.476 speed: 10875 wps
# 9.7% perplexity: 293.800 speed: 10882 wps
# 11.3% perplexity: 292.905 speed: 10887 wps
# 12.9% perplexity: 294.493 speed: 10895 wps
# 14.5% perplexity: 294.483 speed: 10895 wps
# 16.2% perplexity: 295.178 speed: 10899 wps
# 17.8% perplexity: 294.422 speed: 10903 wps
# 19.4% perplexity: 293.470 speed: 10905 wps
# 21.0% perplexity: 291.011 speed: 10907 wps
# 22.6% perplexity: 288.513 speed: 10910 wps
# 24.2% perplexity: 286.434 speed: 10909 wps
# 25.8% perplexity: 284.041 speed: 10910 wps
# 27.5% perplexity: 281.490 speed: 10912 wps
# 29.1% perplexity: 281.068 speed: 10912 wps
# 30.7% perplexity: 279.786 speed: 10913 wps
# 32.3% perplexity: 278.122 speed: 10913 wps
# 33.9% perplexity: 277.220 speed: 10914 wps
# 35.5% perplexity: 275.999 speed: 10915 wps
# 37.2% perplexity: 273.748 speed: 10916 wps
# 38.8% perplexity: 272.680 speed: 10917 wps
# 40.4% perplexity: 272.722 speed: 10917 wps
# 42.0% perplexity: 270.987 speed: 10916 wps
# 43.6% perplexity: 270.844 speed: 10915 wps
# 45.2% perplexity: 270.241 speed: 10916 wps
# 46.8% perplexity: 268.918 speed: 10917 wps
# 48.5% perplexity: 267.895 speed: 10918 wps
# 50.1% perplexity: 267.612 speed: 10918 wps
# 51.7% perplexity: 267.478 speed: 10919 wps
# 53.3% perplexity: 266.860 speed: 10919 wps
# 54.9% perplexity: 266.105 speed: 10918 wps
# 56.5% perplexity: 265.088 speed: 10918 wps
# 58.2% perplexity: 263.720 speed: 10919 wps
# 59.8% perplexity: 262.710 speed: 10919 wps
# 61.4% perplexity: 261.811 speed: 10919 wps
# 63.0% perplexity: 261.225 speed: 10920 wps
# 64.6% perplexity: 260.674 speed: 10919 wps
# 66.2% perplexity: 260.103 speed: 10920 wps
# 67.9% perplexity: 258.917 speed: 10922 wps
# 69.5% perplexity: 257.922 speed: 10922 wps
# 71.1% perplexity: 257.271 speed: 10922 wps
# 72.7% perplexity: 256.970 speed: 10923 wps
# 74.3% perplexity: 256.295 speed: 10925 wps
# 75.9% perplexity: 255.731 speed: 10924 wps
# 77.5% perplexity: 254.818 speed: 10925 wps
# 79.2% perplexity: 254.239 speed: 10926 wps
# 80.8% perplexity: 254.057 speed: 10926 wps
# 82.4% perplexity: 253.862 speed: 10927 wps
# 84.0% perplexity: 253.820 speed: 10927 wps
# 85.6% perplexity: 253.445 speed: 10927 wps
# 87.2% perplexity: 252.866 speed: 10927 wps
# 88.9% perplexity: 252.423 speed: 10928 wps
# 90.5% perplexity: 251.465 speed: 10928 wps
# 92.1% perplexity: 251.228 speed: 10928 wps
# 93.7% perplexity: 250.973 speed: 10929 wps
# 95.3% perplexity: 250.792 speed: 10930 wps
# 96.9% perplexity: 250.490 speed: 10930 wps
# 98.5% perplexity: 250.257 speed: 10931 wps
# 1 training complete, perplexity: 250.223
# 1 validation complete, perplexity: 194.177
# 0.0% perplexity: 281.850 speed: 9068 wps
# 1.6% perplexity: 248.165 speed: 10743 wps
# 3.2% perplexity: 223.244 speed: 10854 wps
# 4.8% perplexity: 215.566 speed: 10885 wps
# 6.5% perplexity: 210.808 speed: 10901 wps
# 8.1% perplexity: 213.798 speed: 10909 wps
# 9.7% perplexity: 217.560 speed: 10921 wps
# 11.3% perplexity: 218.346 speed: 10924 wps
# 12.9% perplexity: 220.974 speed: 10920 wps
# 14.5% perplexity: 221.732 speed: 10920 wps
# 16.2% perplexity: 223.090 speed: 10926 wps
# 17.8% perplexity: 222.729 speed: 10931 wps
# 19.4% perplexity: 222.593 speed: 10931 wps
# 21.0% perplexity: 221.271 speed: 10935 wps
# 22.6% perplexity: 219.976 speed: 10936 wps
# 24.2% perplexity: 219.096 speed: 10939 wps
# 25.8% perplexity: 217.462 speed: 10938 wps
# 27.5% perplexity: 215.768 speed: 10938 wps
# 29.1% perplexity: 216.051 speed: 10938 wps
# 30.7% perplexity: 215.464 speed: 10939 wps
# 32.3% perplexity: 214.520 speed: 10941 wps
# 33.9% perplexity: 214.279 speed: 10942 wps
# 35.5% perplexity: 213.674 speed: 10941 wps
# 37.2% perplexity: 212.267 speed: 10942 wps
# 38.8% perplexity: 211.885 speed: 10942 wps
# 40.4% perplexity: 212.318 speed: 10944 wps
# 42.0% perplexity: 211.240 speed: 10944 wps
# 43.6% perplexity: 211.615 speed: 10945 wps
# 45.2% perplexity: 211.523 speed: 10945 wps
# 46.8% perplexity: 210.736 speed: 10946 wps
# 48.5% perplexity: 210.255 speed: 10946 wps
# 50.1% perplexity: 210.287 speed: 10946 wps
# 51.7% perplexity: 210.507 speed: 10946 wps
# 53.3% perplexity: 210.352 speed: 10945 wps
# 54.9% perplexity: 210.012 speed: 10946 wps
# 56.5% perplexity: 209.455 speed: 10945 wps
# 58.2% perplexity: 208.629 speed: 10946 wps
# 59.8% perplexity: 208.187 speed: 10946 wps
# 61.4% perplexity: 207.747 speed: 10946 wps
# 63.0% perplexity: 207.519 speed: 10945 wps
# 64.6% perplexity: 207.412 speed: 10946 wps
# 66.2% perplexity: 207.155 speed: 10947 wps
# 67.9% perplexity: 206.469 speed: 10948 wps
# 69.5% perplexity: 206.020 speed: 10948 wps
# 71.1% perplexity: 205.679 speed: 10949 wps
# 72.7% perplexity: 205.673 speed: 10948 wps
# 74.3% perplexity: 205.366 speed: 10948 wps
# 75.9% perplexity: 205.191 speed: 10947 wps
# 77.5% perplexity: 204.679 speed: 10947 wps
# 79.2% perplexity: 204.402 speed: 10947 wps
# 80.8% perplexity: 204.513 speed: 10946 wps
# 82.4% perplexity: 204.560 speed: 10946 wps
# 84.0% perplexity: 204.750 speed: 10946 wps
# 85.6% perplexity: 204.700 speed: 10946 wps
# 87.2% perplexity: 204.424 speed: 10947 wps
# 88.9% perplexity: 204.297 speed: 10947 wps
# 90.5% perplexity: 203.719 speed: 10946 wps
# 92.1% perplexity: 203.759 speed: 10946 wps
# 93.7% perplexity: 203.777 speed: 10946 wps
# 95.3% perplexity: 203.866 speed: 10946 wps
# 96.9% perplexity: 203.856 speed: 10946 wps
# 98.5% perplexity: 203.885 speed: 10946 wps
# 2 training complete, perplexity: 204.019
# 2 validation complete, perplexity: 167.935
# 0.0% perplexity: 239.493 speed: 9204 wps
# 1.6% perplexity: 214.307 speed: 10793 wps
# 3.2% perplexity: 192.456 speed: 10872 wps
# 4.8% perplexity: 185.092 speed: 10903 wps
# 6.5% perplexity: 180.659 speed: 10910 wps
# 8.1% perplexity: 182.876 speed: 10915 wps
# 9.7% perplexity: 185.965 speed: 10919 wps
# 11.3% perplexity: 187.139 speed: 10919 wps
# 12.9% perplexity: 189.520 speed: 10925 wps
# 14.5% perplexity: 190.309 speed: 10924 wps
# 16.2% perplexity: 192.148 speed: 10929 wps
# 17.8% perplexity: 191.909 speed: 10935 wps
# 19.4% perplexity: 191.899 speed: 10935 wps
# 21.0% perplexity: 190.916 speed: 10941 wps
# 22.6% perplexity: 189.810 speed: 10939 wps
# 24.2% perplexity: 189.322 speed: 10942 wps
# 25.8% perplexity: 188.227 speed: 10940 wps
# 27.5% perplexity: 186.941 speed: 10940 wps
# 29.1% perplexity: 187.616 speed: 10941 wps
# 30.7% perplexity: 187.437 speed: 10944 wps
# 32.3% perplexity: 186.737 speed: 10947 wps
# 33.9% perplexity: 186.549 speed: 10948 wps
# 35.5% perplexity: 186.246 speed: 10948 wps
# 37.2% perplexity: 185.039 speed: 10947 wps
# 38.8% perplexity: 184.861 speed: 10947 wps
# 40.4% perplexity: 185.341 speed: 10947 wps
# 42.0% perplexity: 184.482 speed: 10948 wps
# 43.6% perplexity: 184.935 speed: 10949 wps
# 45.2% perplexity: 185.018 speed: 10949 wps
# 46.8% perplexity: 184.467 speed: 10950 wps
# 48.5% perplexity: 184.138 speed: 10952 wps
# 50.1% perplexity: 184.250 speed: 10953 wps
# 51.7% perplexity: 184.656 speed: 10953 wps
# 53.3% perplexity: 184.595 speed: 10952 wps
# 54.9% perplexity: 184.448 speed: 10953 wps
# 56.5% perplexity: 184.018 speed: 10953 wps
# 58.2% perplexity: 183.308 speed: 10953 wps
# 59.8% perplexity: 182.973 speed: 10954 wps
# 61.4% perplexity: 182.626 speed: 10954 wps
# 63.0% perplexity: 182.532 speed: 10954 wps
# 64.6% perplexity: 182.490 speed: 10955 wps
# 66.2% perplexity: 182.338 speed: 10955 wps
# 67.9% perplexity: 181.808 speed: 10956 wps
# 69.5% perplexity: 181.500 speed: 10955 wps
# 71.1% perplexity: 181.289 speed: 10955 wps
# 72.7% perplexity: 181.351 speed: 10955 wps
# 74.3% perplexity: 181.143 speed: 10955 wps
# 75.9% perplexity: 181.029 speed: 10955 wps
# 77.5% perplexity: 180.607 speed: 10955 wps
# 79.2% perplexity: 180.428 speed: 10956 wps
# 80.8% perplexity: 180.572 speed: 10956 wps
# 82.4% perplexity: 180.758 speed: 10956 wps
# 84.0% perplexity: 180.964 speed: 10957 wps
# 85.6% perplexity: 181.053 speed: 10957 wps
# 87.2% perplexity: 180.884 speed: 10956 wps
# 88.9% perplexity: 180.830 speed: 10957 wps
# 90.5% perplexity: 180.358 speed: 10957 wps
# 92.1% perplexity: 180.431 speed: 10957 wps
# 93.7% perplexity: 180.457 speed: 10957 wps
# 95.3% perplexity: 180.658 speed: 10957 wps
# 96.9% perplexity: 180.740 speed: 10957 wps
# 98.5% perplexity: 180.874 speed: 10958 wps
# 3 training complete, perplexity: 181.050
# 3 validation complete, perplexity: 154.143
# 0.0% perplexity: 214.612 speed: 9242 wps
# 1.6% perplexity: 191.507 speed: 10779 wps
# 3.2% perplexity: 172.518 speed: 10857 wps
# 4.8% perplexity: 167.244 speed: 10888 wps
# 6.5% perplexity: 163.325 speed: 10908 wps
# 8.1% perplexity: 165.226 speed: 10919 wps
# 9.7% perplexity: 167.774 speed: 10918 wps
# 11.3% perplexity: 169.238 speed: 10922 wps
# 12.9% perplexity: 171.674 speed: 10926 wps
# 14.5% perplexity: 172.565 speed: 10932 wps
# 16.2% perplexity: 174.400 speed: 10931 wps
# 17.8% perplexity: 174.193 speed: 10937 wps
# 19.4% perplexity: 174.310 speed: 10939 wps
# 21.0% perplexity: 173.315 speed: 10941 wps
# 22.6% perplexity: 172.505 speed: 10944 wps
# 24.2% perplexity: 172.042 speed: 10947 wps
# 25.8% perplexity: 171.041 speed: 10949 wps
# 27.5% perplexity: 169.821 speed: 10950 wps
# 29.1% perplexity: 170.339 speed: 10950 wps
# 30.7% perplexity: 170.156 speed: 10954 wps
# 32.3% perplexity: 169.712 speed: 10954 wps
# 33.9% perplexity: 169.593 speed: 10954 wps
# 35.5% perplexity: 169.367 speed: 10952 wps
# 37.2% perplexity: 168.368 speed: 10953 wps
# 38.8% perplexity: 168.337 speed: 10955 wps
# 40.4% perplexity: 168.909 speed: 10955 wps
# 42.0% perplexity: 168.136 speed: 10955 wps
# 43.6% perplexity: 168.613 speed: 10956 wps
# 45.2% perplexity: 168.733 speed: 10955 wps
# 46.8% perplexity: 168.213 speed: 10955 wps
# 48.5% perplexity: 167.859 speed: 10956 wps
# 50.1% perplexity: 167.971 speed: 10956 wps
# 51.7% perplexity: 168.398 speed: 10956 wps
# 53.3% perplexity: 168.458 speed: 10956 wps
# 54.9% perplexity: 168.389 speed: 10957 wps
# 56.5% perplexity: 168.019 speed: 10956 wps
# 58.2% perplexity: 167.394 speed: 10958 wps
# 59.8% perplexity: 167.221 speed: 10958 wps
# 61.4% perplexity: 166.957 speed: 10957 wps
# 63.0% perplexity: 166.948 speed: 10957 wps
# 64.6% perplexity: 166.937 speed: 10958 wps
# 66.2% perplexity: 166.827 speed: 10957 wps
# 67.9% perplexity: 166.426 speed: 10957 wps
# 69.5% perplexity: 166.221 speed: 10958 wps
# 71.1% perplexity: 166.071 speed: 10958 wps
# 72.7% perplexity: 166.227 speed: 10958 wps
# 74.3% perplexity: 166.088 speed: 10958 wps
# 75.9% perplexity: 166.050 speed: 10958 wps
# 77.5% perplexity: 165.648 speed: 10958 wps
# 79.2% perplexity: 165.491 speed: 10958 wps
# 80.8% perplexity: 165.688 speed: 10958 wps
# 82.4% perplexity: 165.905 speed: 10958 wps
# 84.0% perplexity: 166.131 speed: 10957 wps
# 85.6% perplexity: 166.260 speed: 10957 wps
# 87.2% perplexity: 166.183 speed: 10957 wps
# 88.9% perplexity: 166.154 speed: 10957 wps
# 90.5% perplexity: 165.765 speed: 10957 wps
# 92.1% perplexity: 165.869 speed: 10957 wps
# 93.7% perplexity: 165.983 speed: 10957 wps
# 95.3% perplexity: 166.208 speed: 10957 wps
# 96.9% perplexity: 166.343 speed: 10957 wps
# 98.5% perplexity: 166.555 speed: 10957 wps
# 4 training complete, perplexity: 166.760
# 4 validation complete, perplexity: 144.155
# 0.0% perplexity: 204.291 speed: 9232 wps
# 1.6% perplexity: 178.706 speed: 10770 wps
# 3.2% perplexity: 160.189 speed: 10864 wps
# 4.8% perplexity: 154.671 speed: 10901 wps
# 6.5% perplexity: 150.656 speed: 10917 wps
# 8.1% perplexity: 152.435 speed: 10927 wps
# 9.7% perplexity: 155.280 speed: 10939 wps
# 11.3% perplexity: 156.510 speed: 10941 wps
# 12.9% perplexity: 159.206 speed: 10945 wps
# 14.5% perplexity: 160.246 speed: 10942 wps
# 16.2% perplexity: 162.066 speed: 10947 wps
# 17.8% perplexity: 161.880 speed: 10946 wps
# 19.4% perplexity: 162.065 speed: 10945 wps
# 21.0% perplexity: 161.292 speed: 10947 wps
# 22.6% perplexity: 160.495 speed: 10950 wps
# 24.2% perplexity: 160.268 speed: 10949 wps
# 25.8% perplexity: 159.443 speed: 10951 wps
# 27.5% perplexity: 158.328 speed: 10951 wps
# 29.1% perplexity: 159.026 speed: 10953 wps
# 30.7% perplexity: 158.999 speed: 10952 wps
# 32.3% perplexity: 158.596 speed: 10953 wps
# 33.9% perplexity: 158.625 speed: 10952 wps
# 35.5% perplexity: 158.421 speed: 10954 wps
# 37.2% perplexity: 157.581 speed: 10955 wps
# 38.8% perplexity: 157.544 speed: 10955 wps
# 40.4% perplexity: 158.096 speed: 10954 wps
# 42.0% perplexity: 157.434 speed: 10953 wps
# 43.6% perplexity: 157.893 speed: 10954 wps
# 45.2% perplexity: 158.030 speed: 10953 wps
# 46.8% perplexity: 157.455 speed: 10953 wps
# 48.5% perplexity: 157.182 speed: 10953 wps
# 50.1% perplexity: 157.332 speed: 10953 wps
# 51.7% perplexity: 157.750 speed: 10954 wps
# 53.3% perplexity: 157.819 speed: 10955 wps
# 54.9% perplexity: 157.730 speed: 10955 wps
# 56.5% perplexity: 157.337 speed: 10955 wps
# 58.2% perplexity: 156.787 speed: 10954 wps
# 59.8% perplexity: 156.600 speed: 10953 wps
# 61.4% perplexity: 156.358 speed: 10953 wps
# 63.0% perplexity: 156.319 speed: 10953 wps
# 64.6% perplexity: 156.305 speed: 10954 wps
# 66.2% perplexity: 156.219 speed: 10953 wps
# 67.9% perplexity: 155.883 speed: 10954 wps
# 69.5% perplexity: 155.715 speed: 10954 wps
# 71.1% perplexity: 155.585 speed: 10954 wps
# 72.7% perplexity: 155.726 speed: 10954 wps
# 74.3% perplexity: 155.656 speed: 10955 wps
# 75.9% perplexity: 155.653 speed: 10954 wps
# 77.5% perplexity: 155.303 speed: 10955 wps
# 79.2% perplexity: 155.206 speed: 10955 wps
# 80.8% perplexity: 155.421 speed: 10954 wps
# 82.4% perplexity: 155.625 speed: 10954 wps
# 84.0% perplexity: 155.853 speed: 10955 wps
# 85.6% perplexity: 156.004 speed: 10955 wps
# 87.2% perplexity: 155.950 speed: 10955 wps
# 88.9% perplexity: 155.967 speed: 10956 wps
# 90.5% perplexity: 155.595 speed: 10956 wps
# 92.1% perplexity: 155.720 speed: 10956 wps
# 93.7% perplexity: 155.878 speed: 10956 wps
# 95.3% perplexity: 156.110 speed: 10956 wps
# 96.9% perplexity: 156.252 speed: 10956 wps
# 98.5% perplexity: 156.439 speed: 10956 wps
# 5 training complete, perplexity: 156.676
# 5 validation complete, perplexity: 138.684
# 0.0% perplexity: 197.788 speed: 9279 wps
# 1.6% perplexity: 169.610 speed: 10782 wps
# 3.2% perplexity: 152.516 speed: 10882 wps
# 4.8% perplexity: 146.268 speed: 10908 wps
# 6.5% perplexity: 142.641 speed: 10923 wps
# 8.1% perplexity: 144.413 speed: 10925 wps
# 9.7% perplexity: 146.790 speed: 10927 wps
# 11.3% perplexity: 148.334 speed: 10934 wps
# 12.9% perplexity: 150.905 speed: 10934 wps
# 14.5% perplexity: 152.008 speed: 10933 wps
# 16.2% perplexity: 153.494 speed: 10932 wps
# 17.8% perplexity: 153.299 speed: 10933 wps
# 19.4% perplexity: 153.266 speed: 10936 wps
# 21.0% perplexity: 152.465 speed: 10940 wps
# 22.6% perplexity: 151.836 speed: 10941 wps
# 24.2% perplexity: 151.727 speed: 10945 wps
# 25.8% perplexity: 150.860 speed: 10945 wps
# 27.5% perplexity: 149.885 speed: 10945 wps
# 29.1% perplexity: 150.628 speed: 10947 wps
# 30.7% perplexity: 150.524 speed: 10948 wps
# 32.3% perplexity: 150.083 speed: 10947 wps
# 33.9% perplexity: 150.047 speed: 10948 wps
# 35.5% perplexity: 149.925 speed: 10949 wps
# 37.2% perplexity: 149.131 speed: 10950 wps
# 38.8% perplexity: 149.241 speed: 10950 wps
# 40.4% perplexity: 149.829 speed: 10951 wps
# 42.0% perplexity: 149.208 speed: 10951 wps
# 43.6% perplexity: 149.673 speed: 10951 wps
# 45.2% perplexity: 149.842 speed: 10952 wps
# 46.8% perplexity: 149.339 speed: 10953 wps
# 48.5% perplexity: 149.152 speed: 10953 wps
# 50.1% perplexity: 149.286 speed: 10954 wps
# 51.7% perplexity: 149.717 speed: 10954 wps
# 53.3% perplexity: 149.802 speed: 10953 wps
# 54.9% perplexity: 149.771 speed: 10953 wps
# 56.5% perplexity: 149.494 speed: 10954 wps
# 58.2% perplexity: 148.951 speed: 10954 wps
# 59.8% perplexity: 148.788 speed: 10954 wps
# 61.4% perplexity: 148.580 speed: 10953 wps
# 63.0% perplexity: 148.547 speed: 10952 wps
# 64.6% perplexity: 148.557 speed: 10953 wps
# 66.2% perplexity: 148.511 speed: 10952 wps
# 67.9% perplexity: 148.184 speed: 10952 wps
# 69.5% perplexity: 148.052 speed: 10952 wps
# 71.1% perplexity: 147.949 speed: 10953 wps
# 72.7% perplexity: 148.103 speed: 10954 wps
# 74.3% perplexity: 148.027 speed: 10954 wps
# 75.9% perplexity: 148.037 speed: 10954 wps
# 77.5% perplexity: 147.784 speed: 10954 wps
# 79.2% perplexity: 147.710 speed: 10954 wps
# 80.8% perplexity: 147.939 speed: 10954 wps
# 82.4% perplexity: 148.134 speed: 10955 wps
# 84.0% perplexity: 148.380 speed: 10955 wps
# 85.6% perplexity: 148.524 speed: 10955 wps
# 87.2% perplexity: 148.500 speed: 10956 wps
# 88.9% perplexity: 148.526 speed: 10956 wps
# 90.5% perplexity: 148.185 speed: 10957 wps
# 92.1% perplexity: 148.305 speed: 10957 wps
# 93.7% perplexity: 148.429 speed: 10956 wps
# 95.3% perplexity: 148.680 speed: 10957 wps
# 96.9% perplexity: 148.851 speed: 10957 wps
# 98.5% perplexity: 149.070 speed: 10956 wps
# 6 training complete, perplexity: 149.295
# 6 validation complete, perplexity: 133.811
# 0.0% perplexity: 186.832 speed: 9150 wps
# 1.6% perplexity: 161.950 speed: 10791 wps
# 3.2% perplexity: 145.255 speed: 10890 wps
# 4.8% perplexity: 139.573 speed: 10917 wps
# 6.5% perplexity: 136.286 speed: 10924 wps
# 8.1% perplexity: 137.725 speed: 10926 wps
# 9.7% perplexity: 140.187 speed: 10935 wps
# 11.3% perplexity: 141.590 speed: 10933 wps
# 12.9% perplexity: 144.148 speed: 10937 wps
# 14.5% perplexity: 145.298 speed: 10943 wps
# 16.2% perplexity: 146.919 speed: 10946 wps
# 17.8% perplexity: 146.720 speed: 10950 wps
# 19.4% perplexity: 146.688 speed: 10950 wps
# 21.0% perplexity: 145.992 speed: 10953 wps
# 22.6% perplexity: 145.353 speed: 10953 wps
# 24.2% perplexity: 145.215 speed: 10955 wps
# 25.8% perplexity: 144.484 speed: 10954 wps
# 27.5% perplexity: 143.518 speed: 10952 wps
# 29.1% perplexity: 144.192 speed: 10956 wps
# 30.7% perplexity: 144.095 speed: 10953 wps
# 32.3% perplexity: 143.800 speed: 10954 wps
# 33.9% perplexity: 143.819 speed: 10954 wps
# 35.5% perplexity: 143.714 speed: 10955 wps
# 37.2% perplexity: 142.930 speed: 10954 wps
# 38.8% perplexity: 142.998 speed: 10955 wps
# 40.4% perplexity: 143.577 speed: 10956 wps
# 42.0% perplexity: 142.961 speed: 10955 wps
# 43.6% perplexity: 143.389 speed: 10956 wps
# 45.2% perplexity: 143.540 speed: 10955 wps
# 46.8% perplexity: 143.100 speed: 10953 wps
# 48.5% perplexity: 142.860 speed: 10952 wps
# 50.1% perplexity: 143.020 speed: 10952 wps
# 51.7% perplexity: 143.492 speed: 10952 wps
# 53.3% perplexity: 143.640 speed: 10952 wps
# 54.9% perplexity: 143.616 speed: 10952 wps
# 56.5% perplexity: 143.317 speed: 10952 wps
# 58.2% perplexity: 142.850 speed: 10952 wps
# 59.8% perplexity: 142.731 speed: 10952 wps
# 61.4% perplexity: 142.577 speed: 10952 wps
# 63.0% perplexity: 142.591 speed: 10952 wps
# 64.6% perplexity: 142.600 speed: 10953 wps
# 66.2% perplexity: 142.579 speed: 10952 wps
# 67.9% perplexity: 142.327 speed: 10953 wps
# 69.5% perplexity: 142.248 speed: 10953 wps
# 71.1% perplexity: 142.189 speed: 10953 wps
# 72.7% perplexity: 142.300 speed: 10952 wps
# 74.3% perplexity: 142.210 speed: 10953 wps
# 75.9% perplexity: 142.205 speed: 10953 wps
# 77.5% perplexity: 141.928 speed: 10954 wps
# 79.2% perplexity: 141.888 speed: 10955 wps
# 80.8% perplexity: 142.101 speed: 10956 wps
# 82.4% perplexity: 142.339 speed: 10956 wps
# 84.0% perplexity: 142.591 speed: 10955 wps
# 85.6% perplexity: 142.755 speed: 10955 wps
# 87.2% perplexity: 142.729 speed: 10955 wps
# 88.9% perplexity: 142.739 speed: 10956 wps
# 90.5% perplexity: 142.402 speed: 10956 wps
# 92.1% perplexity: 142.525 speed: 10955 wps
# 93.7% perplexity: 142.654 speed: 10956 wps
# 95.3% perplexity: 142.900 speed: 10956 wps
# 96.9% perplexity: 143.096 speed: 10956 wps
# 98.5% perplexity: 143.301 speed: 10956 wps
# 7 training complete, perplexity: 143.533
# 7 validation complete, perplexity: 129.305
# 0.0% perplexity: 185.938 speed: 9216 wps
# 1.6% perplexity: 154.615 speed: 10768 wps
# 3.2% perplexity: 138.793 speed: 10871 wps
# 4.8% perplexity: 133.972 speed: 10883 wps
# 6.5% perplexity: 131.273 speed: 10910 wps
# 8.1% perplexity: 132.675 speed: 10922 wps
# 9.7% perplexity: 135.203 speed: 10926 wps
# 11.3% perplexity: 136.874 speed: 10935 wps
# 12.9% perplexity: 139.674 speed: 10942 wps
# 14.5% perplexity: 140.824 speed: 10944 wps
# 16.2% perplexity: 142.299 speed: 10947 wps
# 17.8% perplexity: 142.171 speed: 10946 wps
# 19.4% perplexity: 142.260 speed: 10945 wps
# 21.0% perplexity: 141.522 speed: 10947 wps
# 22.6% perplexity: 140.759 speed: 10949 wps
# 24.2% perplexity: 140.640 speed: 10951 wps
# 25.8% perplexity: 139.875 speed: 10951 wps
# 27.5% perplexity: 138.971 speed: 10952 wps
# 29.1% perplexity: 139.695 speed: 10952 wps
# 30.7% perplexity: 139.766 speed: 10954 wps
# 32.3% perplexity: 139.557 speed: 10954 wps
# 33.9% perplexity: 139.522 speed: 10953 wps
# 35.5% perplexity: 139.415 speed: 10952 wps
# 37.2% perplexity: 138.726 speed: 10953 wps
# 38.8% perplexity: 138.910 speed: 10954 wps
# 40.4% perplexity: 139.442 speed: 10953 wps
# 42.0% perplexity: 138.841 speed: 10955 wps
# 43.6% perplexity: 139.300 speed: 10957 wps
# 45.2% perplexity: 139.503 speed: 10956 wps
# 46.8% perplexity: 139.108 speed: 10955 wps
# 48.5% perplexity: 138.981 speed: 10956 wps
# 50.1% perplexity: 139.137 speed: 10955 wps
# 51.7% perplexity: 139.545 speed: 10955 wps
# 53.3% perplexity: 139.731 speed: 10955 wps
# 54.9% perplexity: 139.747 speed: 10955 wps
# 56.5% perplexity: 139.517 speed: 10956 wps
# 58.2% perplexity: 139.055 speed: 10955 wps
# 59.8% perplexity: 138.939 speed: 10955 wps
# 61.4% perplexity: 138.756 speed: 10956 wps
# 63.0% perplexity: 138.768 speed: 10957 wps
# 64.6% perplexity: 138.767 speed: 10957 wps
# 66.2% perplexity: 138.705 speed: 10957 wps
# 67.9% perplexity: 138.452 speed: 10958 wps
# 69.5% perplexity: 138.340 speed: 10958 wps
# 71.1% perplexity: 138.267 speed: 10958 wps
# 72.7% perplexity: 138.401 speed: 10959 wps
# 74.3% perplexity: 138.360 speed: 10959 wps
# 75.9% perplexity: 138.378 speed: 10960 wps
# 77.5% perplexity: 138.128 speed: 10961 wps
# 79.2% perplexity: 138.046 speed: 10960 wps
# 80.8% perplexity: 138.233 speed: 10960 wps
# 82.4% perplexity: 138.455 speed: 10960 wps
# 84.0% perplexity: 138.708 speed: 10960 wps
# 85.6% perplexity: 138.884 speed: 10960 wps
# 87.2% perplexity: 138.881 speed: 10961 wps
# 88.9% perplexity: 138.952 speed: 10960 wps
# 90.5% perplexity: 138.667 speed: 10960 wps
# 92.1% perplexity: 138.807 speed: 10959 wps
# 93.7% perplexity: 138.951 speed: 10960 wps
# 95.3% perplexity: 139.181 speed: 10960 wps
# 96.9% perplexity: 139.364 speed: 10960 wps
# 98.5% perplexity: 139.578 speed: 10959 wps
# 8 training complete, perplexity: 139.779
# 8 validation complete, perplexity: 125.957
# 0.0% perplexity: 180.196 speed: 9235 wps
# 1.6% perplexity: 150.435 speed: 10751 wps
# 3.2% perplexity: 135.401 speed: 10860 wps
# 4.8% perplexity: 129.730 speed: 10888 wps
# 6.5% perplexity: 126.840 speed: 10907 wps
# 8.1% perplexity: 128.390 speed: 10914 wps
# 9.7% perplexity: 130.576 speed: 10920 wps
# 11.3% perplexity: 132.095 speed: 10922 wps
# 12.9% perplexity: 135.073 speed: 10930 wps
# 14.5% perplexity: 135.844 speed: 10932 wps
# 16.2% perplexity: 137.284 speed: 10934 wps
# 17.8% perplexity: 137.225 speed: 10937 wps
# 19.4% perplexity: 137.235 speed: 10941 wps
# 21.0% perplexity: 136.714 speed: 10942 wps
# 22.6% perplexity: 136.024 speed: 10942 wps
# 24.2% perplexity: 136.046 speed: 10944 wps
# 25.8% perplexity: 135.423 speed: 10944 wps
# 27.5% perplexity: 134.567 speed: 10945 wps
# 29.1% perplexity: 135.199 speed: 10944 wps
# 30.7% perplexity: 135.273 speed: 10945 wps
# 32.3% perplexity: 135.062 speed: 10945 wps
# 33.9% perplexity: 135.157 speed: 10946 wps
# 35.5% perplexity: 135.052 speed: 10946 wps
# 37.2% perplexity: 134.383 speed: 10948 wps
# 38.8% perplexity: 134.507 speed: 10950 wps
# 40.4% perplexity: 135.038 speed: 10950 wps
# 42.0% perplexity: 134.434 speed: 10951 wps
# 43.6% perplexity: 134.913 speed: 10952 wps
# 45.2% perplexity: 135.081 speed: 10953 wps
# 46.8% perplexity: 134.705 speed: 10955 wps
# 48.5% perplexity: 134.530 speed: 10955 wps
# 50.1% perplexity: 134.667 speed: 10954 wps
# 51.7% perplexity: 135.059 speed: 10955 wps
# 53.3% perplexity: 135.214 speed: 10954 wps
# 54.9% perplexity: 135.177 speed: 10953 wps
# 56.5% perplexity: 134.954 speed: 10954 wps
# 58.2% perplexity: 134.531 speed: 10954 wps
# 59.8% perplexity: 134.348 speed: 10954 wps
# 61.4% perplexity: 134.211 speed: 10954 wps
# 63.0% perplexity: 134.236 speed: 10954 wps
# 64.6% perplexity: 134.248 speed: 10954 wps
# 66.2% perplexity: 134.194 speed: 10954 wps
# 67.9% perplexity: 133.952 speed: 10954 wps
# 69.5% perplexity: 133.900 speed: 10955 wps
# 71.1% perplexity: 133.877 speed: 10956 wps
# 72.7% perplexity: 134.032 speed: 10956 wps
# 74.3% perplexity: 133.951 speed: 10956 wps
# 75.9% perplexity: 133.957 speed: 10956 wps
# 77.5% perplexity: 133.682 speed: 10956 wps
# 79.2% perplexity: 133.681 speed: 10957 wps
# 80.8% perplexity: 133.900 speed: 10957 wps
# 82.4% perplexity: 134.155 speed: 10957 wps
# 84.0% perplexity: 134.390 speed: 10958 wps
# 85.6% perplexity: 134.583 speed: 10957 wps
# 87.2% perplexity: 134.616 speed: 10958 wps
# 88.9% perplexity: 134.675 speed: 10958 wps
# 90.5% perplexity: 134.369 speed: 10958 wps
# 92.1% perplexity: 134.520 speed: 10958 wps
# 93.7% perplexity: 134.640 speed: 10958 wps
# 95.3% perplexity: 134.866 speed: 10958 wps
# 96.9% perplexity: 135.034 speed: 10958 wps
# 98.5% perplexity: 135.270 speed: 10958 wps
# 9 training complete, perplexity: 135.481
# 9 validation complete, perplexity: 124.937
# testing complete, perplexity: 119.631
